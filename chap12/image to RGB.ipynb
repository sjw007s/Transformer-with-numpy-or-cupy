# %%
from PIL import Image
for i in range(11000):
    source_image = "image_data/"+str(i)+".png"
    resize_image_ = "image_data/"+str(i)+"_resize_80_40_hard.png"
    image = Image.open(source_image)
    # resize 할 이미지 사이즈 
    resize_image = image.resize((80, 40))
    # 저장할 파일 Type : JPEG, PNG 등 
    # 저장할 때 Quality 수준 : 보통 95 사용 
    resize_image.save(resize_image_, "PNG")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-6bdd942116e0> in <module>
#       3     source_image = "image_data/"+str(i)+".png"
#       4     resize_image_ = "image_data/"+str(i)+"_resize_80_40_hard.png"
# ----> 5     image = Image.open(source_image)
#       6     # resize 할 이미지 사이즈
#       7     resize_image = image.resize((80, 40))
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image_data/2200.png'

# %%
from PIL import Image
for i in range(1):
    source_image = "image_data/"+str(i)+".png"
    resize_image_ = "image_data/"+str(i)+"_resize_80_40_hard.png"
    
    image = Image.open(source_image)
    width, height = image.size
    print(width, height)
    image=image.crop((300,20,900,600)) #1202 622
    
    
    resize_image = image.resize((80, 40))
    # 저장할 파일 Type : JPEG, PNG 등 
    # 저장할 때 Quality 수준 : 보통 95 사용 
    resize_image.save(resize_image_, "PNG")
# Out:
# 1212 632

# %%
from PIL import Image
for i in range(11000):
    source_image = "image_data/"+str(i)+".png"
    resize_image_ = "image_data/"+str(i)+"_resize_80_40_hard.png"
    
    image = Image.open(source_image)
    width, height = image.size
    print(width, height)
    image=image.crop((400,20,1200,860)) #1202 622
    
    
    resize_image = image.resize((80, 40))
    # 저장할 파일 Type : JPEG, PNG 등 
    # 저장할 때 Quality 수준 : 보통 95 사용 
    resize_image.save(resize_image_, "PNG")
# Out:
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# 1202 622
# ...

# %%
from PIL import Image
import csv
for i in range(1):
    im = Image.open("image_data/"+str(i)+".png") #Can be many different formats.
    width, height = im.size
    print(width, height)
    pix = im.load()
    #print (im.size) #Get the width and hight of the image for iterating over
    for j in range(height):
        temp_list_r=list()
        temp_list_g=list()
        temp_list_b=list()
        #print("j",j)
        for k in range(width):
            red, green, blue=pix[k,j]
            temp_list_r.append(red)
            temp_list_g.append(green)
            temp_list_b.append(blue)
            #print("k",k)
        with open(str(i)+"_r_"+str(width)+"_"+str(height)+".csv",'a',newline='') as aa:
            writer = csv.writer(aa, delimiter=',')
            writer.writerow(temp_list_r)
        with open(str(i)+"_g_"+str(width)+"_"+str(height)+".csv",'a',newline='') as aa:
            writer = csv.writer(aa, delimiter=',')
            writer.writerow(temp_list_g)

        with open(str(i)+"_b_"+str(width)+"_"+str(height)+".csv",'a',newline='') as aa:
            writer = csv.writer(aa, delimiter=',')
            writer.writerow(temp_list_b)
# Out:
# 1202 622

# %%
from PIL import Image
import csv
for i in range(11000):
    im = Image.open("image_data/"+str(i)+"_resize_80_40_hard.png") #Can be many different formats.
    pix = im.load()
    #print (im.size) #Get the width and hight of the image for iterating over
    for j in range(40):
        temp_list_r=list()
        temp_list_g=list()
        temp_list_b=list()
        for k in range(80):
            red, green, blue=pix[k,j]
            temp_list_r.append(red)
            temp_list_g.append(green)
            temp_list_b.append(blue)
        with open(str(i)+"_r_80_40_hard.csv",'a',newline='') as aa:
            writer = csv.writer(aa, delimiter=',')
            writer.writerow(temp_list_r)
        with open(str(i)+"_g_80_40_hard.csv",'a',newline='') as aa:
            writer = csv.writer(aa, delimiter=',')
            writer.writerow(temp_list_g)

        with open(str(i)+"_b_80_40_hard.csv",'a',newline='') as aa:
            writer = csv.writer(aa, delimiter=',')
            writer.writerow(temp_list_b)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-d76245befe78> in <module>
#       2 import csv
#       3 for i in range(11000):
# ----> 4     im = Image.open("image_data/"+str(i)+"_resize_80_40_hard.png") #Can be many different formats.
#       5     pix = im.load()
#       6     #print (im.size) #Get the width and hight of the image for iterating over
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image_data/2200_resize_80_40_hard.png'
