# %%
# %run ../chap15/gan.ipynb
# %run ../chap15/dataset_gan.ipynb
np.random.seed(int(time.time()))

# %%
dset_pic_gogh = GanDatasetPicture('gogh.jpg')
# Out:
# 0
# 1 256 256 3

# %%
epoch_count=100000000000000
batch_size=1
learning_rate=0.0001
learning_decrease_=0.999
restore_='result_test.csv'
conf_pic = {
    'seed_shape':  [4,4,120],
    'generator':   [
                
                    ['trans_conv',{'ksize':[7,7],'stride':[4,4], 'chn':50,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[7,7],'stride':[4,4], 'chn':40,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[7,7],'stride':[3,3], 'chn':30,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[6,6],'stride':[1,1], 'chn':20,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[4,4],'stride':[2,2], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[10,10], 'stride':[2,2],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[13,13],'stride':[1,1], 'chn':20,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[7,7],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[15,15], 'stride':[1,1],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LBA'}],
                    ['trans_conv',{'ksize':[1,1],'stride':[1,1], 'chn':3,'actfunc':'none','actions': 'LA'}],
                    #['no_trans_conv',{'actfunc':'none'}],
                    #['dropout', {'keep_prob':0.5}],
        
                    #['no_trans_conv',{'actfunc':'relu'}],
                    #['no_trans_conv',{'actfunc':'relu'}],
                    #['dropout', {'keep_prob':0.5}],
                    #['no_trans_conv',{'actfunc':'sigmoid'}],
                    #['no_trans_conv',{'actfunc':'none'}],
             
                   
         
                    #['trans_conv',{'ksize':[12,12], 'chn':1,'actfunc':'sigmoid'}],
                    ],
    
                    
    'discriminor': [
                    ['conv',{'ksize':[10,10], 'stride':[3,3],'chn':50,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #'trans_conv',{'ksize':[5,5], 'chn':150,'actfunc':'leaky_relu','actions': 'LAB'}],
                    ['conv',{'ksize':[10,10], 'stride':[4,4],'chn':40,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['conv',{'ksize':[10,10], 'stride':[3,3],'chn':30,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    
                    ['conv',{'ksize':[6,6], 'stride':[1,1],'chn':20,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[3,3], 'stride':[1,1],'chn':30,'padding':'VALID','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['dropout', {'keep_prob':0.5}],
                    #['conv',{'ksize':[7,7], 'stride':[3,3],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LAB'}],
                    #'trans_conv',{'ksize':[10,10], 'chn':50,'actfunc':'leaky_relu','actions': 'LAB'}],
                    ['conv',{'ksize':[4,4], 'stride':[1,1],'chn':1,'padding':'VALID','actfunc':'none','actions': 'LA'}],
                    #['trans_conv',{'ksize':[19,19], 'chn':30,'actfunc':'leaky_relu'}],
                    #['conv',{'ksize':[20,20], 'stride':[1,1],'chn':1,'padding':'VALID','actfunc':'sigmoid'}],

                    ['logic_full', {'width':1}]
                   ] #no full but for code coherence
}
#0.4 1
gan_pic_gogh = Gan("지스트사진_90_90", dset_pic_gogh,
                        conf_pic, dump_structure=True)






gan_pic_gogh.exec_all(epoch_count=100000,batch_size=batch_size, 
                        learning_rate=learning_rate,show_params=0, report=1, show_cnt=0,learning_decrease=learning_decrease_,resotre_=restore_)

# %%
epoch_count=100000000000000
batch_size=1
learning_rate=0.00001
learning_decrease_=0.999
restore_='result_test.csv'
conf_pic = {
    'seed_shape':  [4,4,120],
    'generator':   [
                
                    ['trans_conv',{'ksize':[7,7],'stride':[4,4], 'chn':50,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[7,7],'stride':[4,4], 'chn':40,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[7,7],'stride':[3,3], 'chn':30,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['no_trans_conv',{'actfunc':'none'}],
                    ['trans_conv',{'ksize':[6,6],'stride':[1,1], 'chn':20,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[4,4],'stride':[2,2], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[10,10], 'stride':[2,2],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[13,13],'stride':[1,1], 'chn':20,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[7,7],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[15,15], 'stride':[1,1],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LBA'}],
                    ['trans_conv',{'ksize':[1,1],'stride':[1,1], 'chn':3,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['no_trans_conv',{'actfunc':'none'}],
                    #['dropout', {'keep_prob':0.5}],
        
                    #['no_trans_conv',{'actfunc':'relu'}],
                    #['no_trans_conv',{'actfunc':'relu'}],
                    #['dropout', {'keep_prob':0.5}],
                    #['no_trans_conv',{'actfunc':'sigmoid'}],
                    #['no_trans_conv',{'actfunc':'none'}],
             
                   
         
                    #['trans_conv',{'ksize':[12,12], 'chn':1,'actfunc':'sigmoid'}],
                    ],
    
                    
    'discriminor': [
                    ['conv',{'ksize':[10,10], 'stride':[3,3],'chn':50,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #'trans_conv',{'ksize':[5,5], 'chn':150,'actfunc':'leaky_relu','actions': 'LAB'}],
                    ['conv',{'ksize':[10,10], 'stride':[4,4],'chn':40,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['conv',{'ksize':[10,10], 'stride':[3,3],'chn':30,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    
                    ['conv',{'ksize':[6,6], 'stride':[1,1],'chn':20,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[3,3], 'stride':[1,1],'chn':30,'padding':'VALID','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['dropout', {'keep_prob':0.5}],
                    #['conv',{'ksize':[7,7], 'stride':[3,3],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LAB'}],
                    #'trans_conv',{'ksize':[10,10], 'chn':50,'actfunc':'leaky_relu','actions': 'LAB'}],
                    ['conv',{'ksize':[4,4], 'stride':[1,1],'chn':1,'padding':'VALID','actfunc':'none','actions': 'LA'}],
                    #['trans_conv',{'ksize':[19,19], 'chn':30,'actfunc':'leaky_relu'}],
                    #['conv',{'ksize':[20,20], 'stride':[1,1],'chn':1,'padding':'VALID','actfunc':'sigmoid'}],

                    ['logic_full', {'width':1}]
                   ] #no full but for code coherence
}
#0.4 1
gan_pic_gogh = Gan("지스트사진_90_90", dset_pic_gogh,
                        conf_pic, dump_structure=True)




gan_pic_gogh.load=1
gan_pic_gogh.exec_all(epoch_count=1000, batch_size=batch_size, 
                        learning_rate=learning_rate,show_params=0, report=1, show_cnt=0,learning_decrease=learning_decrease_,resotre_=restore_)
gan_pic_gogh.test()

# %%
epoch_count=100000000000000
batch_size=1
learning_rate=0.0001
learning_decrease_=1
restore_='result_test.csv'
conf_pic = {
    'seed_shape':  [4,4,20],
    'generator':   [
                
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':100,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[7,7],'stride':[4,4], 'chn':380,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':100,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['no_trans_conv',{'actfunc':'none'}],
                    ['trans_conv',{'ksize':[45,45],'stride':[1,1], 'chn':100,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[45,45],'stride':[1,1], 'chn':100,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[45,45],'stride':[1,1], 'chn':100,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':100,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':100,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[10,10], 'stride':[2,2],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[13,13],'stride':[1,1], 'chn':20,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':3,'actfunc':'none','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['no_trans_conv',{'actfunc':'none'}],
                    #['conv',{'ksize':[15,15], 'stride':[1,1],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['trans_conv',{'ksize':[1,1],'stride':[1,1], 'chn':3,'actfunc':'none','actions': 'LA'}],
                    #['no_trans_conv',{'actfunc':'none'}],
                    #['dropout', {'keep_prob':0.5}],
        
                    #['no_trans_conv',{'actfunc':'relu'}],
                    #['no_trans_conv',{'actfunc':'relu'}],
                    #['dropout', {'keep_prob':0.5}],
                    #['no_trans_conv',{'actfunc':'sigmoid'}],
                    #['no_trans_conv',{'actfunc':'none'}],
                    ],
    
                    
    'discriminor': [
                    ['conv',{'ksize':[10,10], 'stride':[3,3],'chn':150,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #'trans_conv',{'ksize':[5,5], 'chn':150,'actfunc':'leaky_relu','actions': 'LAB'}],
                    ['conv',{'ksize':[10,10], 'stride':[2,2],'chn':80,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['conv',{'ksize':[10,10], 'stride':[3,3],'chn':40,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    
                    ['conv',{'ksize':[6,6], 'stride':[1,1],'chn':20,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[3,3], 'stride':[1,1],'chn':30,'padding':'VALID','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['dropout', {'keep_prob':0.5}],
                    #['conv',{'ksize':[7,7], 'stride':[3,3],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LAB'}],
                    #'trans_conv',{'ksize':[10,10], 'chn':50,'actfunc':'leaky_relu','actions': 'LAB'}],
                    ['conv',{'ksize':[4,4], 'stride':[1,1],'chn':1,'padding':'VALID','actfunc':'none','actions': 'LA'}],
                    #['trans_conv',{'ksize':[19,19], 'chn':30,'actfunc':'leaky_relu'}],
                    #['conv',{'ksize':[20,20], 'stride':[1,1],'chn':1,'padding':'VALID','actfunc':'sigmoid'}],

                    ['logic_full', {'width':1}]
                   ] #no full but for code coherence
}
#0.4 1
gan_pic_gogh = Gan("지스트사진_256_256_one", dset_pic_gogh,
                        conf_pic, dump_structure=True)




gan_pic_gogh.exec_all(epoch_count=1000, batch_size=batch_size, 
                        learning_rate=learning_rate,show_params=0, report=1, show_cnt=0,learning_decrease=learning_decrease_,resotre_=restore_)
gan_pic_gogh.test()
# Out:
# 1: trans_conv, [4, 4, 20]=>[28, 28, 100] pm:25x25x20x100+100=1250100
# 2: dropout, [28, 28, 100]=>[28, 28, 100]
# 3: trans_conv, [28, 28, 100]=>[52, 52, 100] pm:25x25x100x100+100=6250100
# 4: dropout, [52, 52, 100]=>[52, 52, 100]
# 5: trans_conv, [52, 52, 100]=>[96, 96, 100] pm:45x45x100x100+100=20250100
# 6: dropout, [96, 96, 100]=>[96, 96, 100]
# 7: trans_conv, [96, 96, 100]=>[140, 140, 100] pm:45x45x100x100+100=20250100
# 8: dropout, [140, 140, 100]=>[140, 140, 100]
# 9: trans_conv, [140, 140, 100]=>[184, 184, 100] pm:45x45x100x100+100=20250100
# 10: dropout, [184, 184, 100]=>[184, 184, 100]
# 11: trans_conv, [184, 184, 100]=>[208, 208, 100] pm:25x25x100x100+100=6250100
# 12: dropout, [208, 208, 100]=>[208, 208, 100]
# 13: trans_conv, [208, 208, 100]=>[232, 232, 100] pm:25x25x100x100+100=6250100
# 14: dropout, [232, 232, 100]=>[232, 232, 100]
# 15: trans_conv, [232, 232, 100]=>[256, 256, 3] pm:25x25x100x3+3=187503
# 16: no_trans_conv, [256, 256, 3]=>[256, 256, 3]
# ...

# %%
epoch_count=100000000000000
batch_size=1
learning_rate=0.00001
learning_decrease_=1
restore_='result_test.csv'
conf_pic = {
    'seed_shape':  [4,4,20],
    'generator':   [
                
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':30,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[7,7],'stride':[4,4], 'chn':380,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':20,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['no_trans_conv',{'actfunc':'none'}],
                    ['trans_conv',{'ksize':[45,45],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[45,45],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[45,45],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[10,10], 'stride':[2,2],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':10,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    #['trans_conv',{'ksize':[13,13],'stride':[1,1], 'chn':20,'actfunc':'leaky_relu','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['trans_conv',{'ksize':[25,25],'stride':[1,1], 'chn':3,'actfunc':'none','actions': 'LA'}],
                    #['dropout', {'keep_prob':0.8}],
                    ['no_trans_conv',{'actfunc':'none'}],
                    #['conv',{'ksize':[15,15], 'stride':[1,1],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['trans_conv',{'ksize':[1,1],'stride':[1,1], 'chn':3,'actfunc':'none','actions': 'LA'}],
                    #['no_trans_conv',{'actfunc':'none'}],
                    #['dropout', {'keep_prob':0.5}],
        
                    #['no_trans_conv',{'actfunc':'relu'}],
                    #['no_trans_conv',{'actfunc':'relu'}],
                    #['dropout', {'keep_prob':0.5}],
                    #['no_trans_conv',{'actfunc':'sigmoid'}],
                    #['no_trans_conv',{'actfunc':'none'}],
                    ],
    
                    
    'discriminor': [
                    ['conv',{'ksize':[10,10], 'stride':[3,3],'chn':150,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #'trans_conv',{'ksize':[5,5], 'chn':150,'actfunc':'leaky_relu','actions': 'LAB'}],
                    ['conv',{'ksize':[10,10], 'stride':[2,2],'chn':80,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    ['conv',{'ksize':[10,10], 'stride':[3,3],'chn':40,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    
                    ['conv',{'ksize':[6,6], 'stride':[1,1],'chn':20,'padding':'VALID','actfunc':'leaky_relu','actions': 'LA'}],
                    ['dropout', {'keep_prob':0.8}],
                    #['conv',{'ksize':[3,3], 'stride':[1,1],'chn':30,'padding':'VALID','actfunc':'leaky_relu','actions': 'LBA'}],
                    #['dropout', {'keep_prob':0.5}],
                    #['conv',{'ksize':[7,7], 'stride':[3,3],'chn':20,'padding':'SAME','actfunc':'leaky_relu','actions': 'LAB'}],
                    #'trans_conv',{'ksize':[10,10], 'chn':50,'actfunc':'leaky_relu','actions': 'LAB'}],
                    ['conv',{'ksize':[4,4], 'stride':[1,1],'chn':1,'padding':'VALID','actfunc':'none','actions': 'LA'}],
                    #['trans_conv',{'ksize':[19,19], 'chn':30,'actfunc':'leaky_relu'}],
                    #['conv',{'ksize':[20,20], 'stride':[1,1],'chn':1,'padding':'VALID','actfunc':'sigmoid'}],

                    ['logic_full', {'width':1}]
                   ] #no full but for code coherence
}
#0.4 1
gan_pic_gogh = Gan("지스트사진_256_256_one", dset_pic_gogh,
                        conf_pic, dump_structure=True)


gan_pic_gogh.load=1

gan_pic_gogh.exec_all(epoch_count=1000, batch_size=batch_size, 
                        learning_rate=learning_rate,show_params=0, report=1, show_cnt=0,learning_decrease=learning_decrease_,resotre_=restore_)
gan_pic_gogh.test()
